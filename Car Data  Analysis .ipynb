# %% [markdown]
# **Car Data  Analysis**

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1580147d-3be2-4094-97c4-7c3105816164" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1580147d-3be2-4094-97c4-7c3105816164">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("car_data (1).csv")
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
df.tail() ##We can directly know rows from df.tail(). tail last row is 431. plus 1 in 431 gives you no. of rows.    no need of df.shape
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 427  $38,203          2.4        5.0       197.0      21.0         28.0
# 428  $40,083          2.3        5.0       242.0      20.0         26.0
# 429  $42,573          2.9        6.0       268.0      19.0         26.0
# 430  $24,641          1.9        4.0       170.0      22.0         29.0
# 431  $33,112          2.5        5.0       208.0      20.0         27.0
#
#      Weight  Wheelbase  Length
# 427  3450.0      105.0   186.0
# 428  3450.0      105.0   186.0
# ...

# %%
df.shape
# Out:
# (432, 15)

# %%
df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
df_updated=df.dropna()

# %%
df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
df_updated.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
df.shape
# Out:
# (432, 15)

# %%
df_updated.shape
# Out:
# (426, 15)

# %%
df_updated.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
df_updated["Origin"].value_counts()
# Out:
# Origin
# Asia      156
# USA       147
# Europe    123
# Name: count, dtype: int64

# %%
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
df_updated["Type"].value_counts()
# Out:
# Type
# Sedan     262
# SUV        60
# Sports     47
# Wagon      30
# Truck      24
# Hybrid      3
# Name: count, dtype: int64

# %%
df_updated.Cylinders.value_counts() #We can only access 1 column using this
# Out:
# Cylinders
# 6.0     190
# 4.0     136
# 8.0      87
# 5.0       7
# 12.0      3
# 10.0      2
# 3.0       1
# Name: count, dtype: int64

# %% [markdown]
# I wanna check multiple types of cars available in my dataset

# %%
df_updated[["Type","Origin","Cylinders","Horsepower","Length"]].value_counts()
# Out:
# Type    Origin  Cylinders  Horsepower  Length
# Sedan   USA     8.0        224.0       212.0     5
#                 4.0        140.0       185.0     5
#         Europe  6.0        215.0       178.0     4
# Sports  Europe  6.0        315.0       175.0     3
# Sedan   USA     4.0        150.0       191.0     3
#                                                 ..
# Truck   USA     8.0        345.0       221.0     1
# SUV     Asia    6.0        240.0       183.0     1
#                            230.0       186.0     1
#                                        185.0     1
#                            193.0       178.0     1
# Name: count, Length: 335, dtype: int64

# %%
df_updated[df_updated['Origin']=='Europe'] #Shows only the rows where the origin is Europe.
# Out:
#       Make                      Model   Type  Origin DriveTrain      MSRP  \
# 7     Audi                A4 1.8T 4dr  Sedan  Europe      Front  $25,940
# 8     Audi     A41.8T convertible 2dr  Sedan  Europe      Front  $35,940
# 9     Audi                 A4 3.0 4dr  Sedan  Europe      Front  $31,840
# 10    Audi  A4 3.0 Quattro 4dr manual  Sedan  Europe        All  $33,430
# 11    Audi    A4 3.0 Quattro 4dr auto  Sedan  Europe        All  $34,480
# ..     ...                        ...    ...     ...        ...       ...
# 427  Volvo    C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo    C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo                 S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                        V40  Wagon  Europe      Front  $26,135
# 431  Volvo                       XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
temp=df_updated[df_updated['Origin']=='Europe'] #Stores only the rows where the origin is in USA in temp variable.
temp.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3713259072.py in <cell line: 0>()
# ----> 1 temp=df_updated[df_updated['Origin']=='Europe'] #Stores only the rows where the origin is in USA in temp variable.
#       2 temp.shape
#
# NameError: name 'df_updated' is not defined

# %%
df_updated[(df_updated.Origin=="USA") | (df_updated.Origin=="Europe")]
# Out:
#       Make                      Model   Type  Origin DriveTrain      MSRP  \
# 7     Audi                A4 1.8T 4dr  Sedan  Europe      Front  $25,940
# 8     Audi     A41.8T convertible 2dr  Sedan  Europe      Front  $35,940
# 9     Audi                 A4 3.0 4dr  Sedan  Europe      Front  $31,840
# 10    Audi  A4 3.0 Quattro 4dr manual  Sedan  Europe        All  $33,430
# 11    Audi    A4 3.0 Quattro 4dr auto  Sedan  Europe        All  $34,480
# ..     ...                        ...    ...     ...        ...       ...
# 427  Volvo    C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo    C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo                 S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                        V40  Wagon  Europe      Front  $26,135
# 431  Volvo                       XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
temp=df_updated[(df_updated.Origin=="Asia") | (df_updated.Origin=="USA") ]
temp["Origin"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2794728894.py in <cell line: 0>()
# ----> 1 temp=df_updated[(df_updated.Origin=="Asia") | (df_updated.Origin=="USA") ]
#       2 temp["Origin"].value_counts()
#
# NameError: name 'df_updated' is not defined

# %%
df_updated.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
df_updated[df_updated["Weight"]>4000]
# Out:
#            Make                           Model    Type  Origin DriveTrain  \
# 0         Acura                             MDX     SUV    Asia        All
# 15         Audi  A4 3.0 Quattro convertible 2dr   Sedan  Europe        All
# 17         Audi              A6 4.2 Quattro 4dr   Sedan  Europe        All
# 18         Audi                A8 L Quattro 4dr   Sedan  Europe        All
# 20         Audi                        RS 6 4dr  Sports  Europe      Front
# ..          ...                             ...     ...     ...        ...
# 405  Volkswagen                      Touareg V6     SUV  Europe        All
# 415  Volkswagen                     Phaeton 4dr   Sedan  Europe      Front
# 416  Volkswagen                 Phaeton W12 4dr   Sedan  Europe      Front
# 419  Volkswagen                       Passat W8   Wagon  Europe      Front
# 420       Volvo                         XC90 T6     SUV  Europe        All
#
# ...

# %%
greaterweight=df_updated[df_updated["Weight"]>4000]
greaterweight.shape
# Out:
# (103, 15)

# %%
lessweight=df_updated[~(df_updated["Weight"]>4000)] #negation used here ~
lessweight.shape
# df_updated[df_updated["Weight"]>3000].value_counts()  . Just for practise
# Out:
# (323, 15)

# %%
lessweight["Weight"].max()
# Out:
# 3992.0

# %%
lessweight["Weight"].min()
# Out:
# 1850.0

# %%
df_updated.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
df_updated["MPG_City"]=df_updated["MPG_City"]+3
# Out:
# /tmp/ipython-input-946203966.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_updated["MPG_City"]=df_updated["MPG_City"]+3

# %%
df_updated.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      20.0         23.0  4451.0
# 1         2.0        4.0       200.0      27.0         31.0  2778.0
# 2         2.4        4.0       200.0      25.0         29.0  3230.0
# 3         3.2        6.0       270.0      23.0         28.0  3575.0
# 4         3.5        6.0       225.0      21.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0
